# %%
# !nvidia-smi
# Out:
# Sun Dec 25 23:30:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    24W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import sys
sys.path.insert(0, '/content/gdrive/My Drive/Protein')

# %%
from torch.utils.data import DataLoader
from model_builder import GRU  
from tensorflow.keras.preprocessing.sequence import pad_sequences
from torch.utils.data import Dataset
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
import engine
import torch
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
from pathlib import Path
import os

# %%
class Config:

    def __init__(self):
        self.ROOT_PATH = "/content/gdrive/My Drive/Protein/dataset/"
        self.TRAIN_PATH = os.path.join(self.ROOT_PATH, "train/")
        self.VAL_PATH = os.path.join(self.ROOT_PATH, "dev/")
        self.TEST_PATH = os.path.join(self.ROOT_PATH, "test/")
        self.batch_size = 32
        self.number_family = 250

        #Amino Acids most common use
        self.AMINO = ['A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K', 'L',
                'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y']    

cfg = Config()

class Tools:
    def __init__(self):
        pass

    def create_dict(self, codes):
        self.char_dict = {}
        for index, val in enumerate(codes):
            self.char_dict[val] = index+1

        return self.char_dict

    def read_data(self, data_path ,partition):
        self.data = []
        for fn in os.listdir(os.path.join(data_path, partition)):
            with open(os.path.join(data_path, partition, fn)) as f:
                self.data.append(pd.read_csv(f, index_col=None))
        return pd.concat(self.data)

    def find_common_family(self, thres=250):
        self.df_train = self.read_data(cfg.ROOT_PATH, 'train')
        self.commonLables = self.df_train.family_accession.value_counts()[:thres]

        return self.commonLables

# %%
class DatasetProtein(Dataset):
    def __init__(self, root, split, amino, common_family, encoding="integer", total_sample_size=541, max_size=250, device='cuda'):
        self.root = root
        self.split = split
        self.device = device
        self.max_size = max_size
        self.total_sample_size = total_sample_size
        self.save_path = os.path.join("/content/gdrive/My Drive/Protein/data/", self.split + 'no_categorical_data.pth')
        self.tool = Tools()
        self.amino = amino #lis of common amino acids
        self.data_encode = encoding
        self.common_family=common_family

        if os.path.exists(self.save_path):
            print(f'Loading dataset {self.split} ...')
            self.filtered_data = self.filter_data()
            pth_dataset = torch.load(self.save_path)
            self.data, self.labels = pth_dataset['data'].to(self.device), pth_dataset['label'].to(self.device)
            print(f"Dataset {self.split} loaded !")
        else:
            print(f"File {self.save_path} does not exist. Creating dataset...")  
            self.data, self.labels = self.get_dataset()
            self.data, self.labels = torch.from_numpy(self.data), torch.from_numpy(self.labels)
            data_dict = {"data": self.data, "label": self.labels}
            self.data, self.labels = self.data.to(self.device), self.labels.to(self.device)  
            print(f"Dataset {self.split} created !")
            torch.save(data_dict, self.save_path)
            print(f"File {self.save_path} Saved!")

    def load(self):
        self.data = []
        for fn in os.listdir(os.path.join(self.root, self.split)):
            with open(os.path.join(self.root, self.split, fn)) as f:
                self.data.append(pd.read_csv(f, index_col=None))
        return pd.concat(self.data)

    #filter for most common family on dataset
    def filter_data(self):
        self.df = self.load()
        self.mask = self.df.family_accession.isin(self.common_family.index.values)

        if self.split == 'train':
            self.filter_df = self.df.loc[self.mask,:]
            self.nrows = len(self.filter_df)
            self.filter_df.groupby('family_accession').head()
            self.filter_df = self.filter_df.groupby('family_accession', group_keys=False).apply(lambda x: x.sample(self.total_sample_size))
            self.filter_df = self.filter_df.sample(frac=1).reset_index(drop=True)
        else:
            self.filter_df = self.df.loc[self.mask, :]
        return self.filter_df

    def get_dataset(self):
        encode = LabelEncoder()
        self.filtered_data = self.filter_data()
        self.amino_dict = self.tool.create_dict(self.amino)
        
        if(self.data_encode=='integer'):
            self.encode_list = []
            for row in self.filtered_data['sequence'].values:
                self.row_encode = []
                for code in row:
                    self.row_encode.append(self.amino_dict.get(code, 0))
                self.encode_list.append(np.array(self.row_encode))

            self.data_encoded = pad_sequences(self.encode_list, maxlen=self.max_size, padding='post', truncating='post')
            if self.split=='train':
                self.label_encoded = encode.fit_transform(self.filtered_data['family_accession'])
            else:
                self.label_encoded = encode.fit_transform(self.filtered_data['family_accession'])           
        return self.data_encoded, self.label_encoded

    def __getitem__(self, index):
        return self.data[index], self.labels[index]

    def __len__(self):
        return len(self.filtered_data)

# %%
cfg = Config()
tool = Tools()
common_family = tool.find_common_family()

device = "cuda" if torch.cuda.is_available() else "cpu"

print(device)
# Out:
# cuda

# %%
train_ds= DatasetProtein(cfg.ROOT_PATH, 'train', cfg.AMINO, common_family=common_family)
test_ds= DatasetProtein(cfg.ROOT_PATH, 'test', cfg.AMINO, common_family=common_family)

train_loader = DataLoader(train_ds, batch_size=32, shuffle=True)
test_loader = DataLoader(test_ds, batch_size=32, shuffle=False)
# Out:
# Loading dataset train ...
# Dataset train loaded !
# Loading dataset test ...
# Dataset test loaded !

# %%
model = GRU(num_embedding=len(cfg.AMINO)+1, output_size=cfg.number_family, embedding_dim=cfg.number_family, hidden_dim=128, n_layers=2)
model.to("cuda")

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = torch.nn.CrossEntropyLoss()

result = engine.train(
    model=model,
    train_dataloader=train_loader,
    test_dataloader=test_loader,
    optimizer=optimizer,
    loss_fn=loss_fn,
    epochs=50,
    device="cuda"
)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 2.1257 | train_acc: 0.4863 | test_loss: 0.9921 | test_acc: 0.7297
# Epoch: 2 | train_loss: 0.6288 | train_acc: 0.8308 | test_loss: 0.4038 | test_acc: 0.8916
# Epoch: 3 | train_loss: 0.3335 | train_acc: 0.9082 | test_loss: 0.2690 | test_acc: 0.9238
# Epoch: 4 | train_loss: 0.2084 | train_acc: 0.9430 | test_loss: 0.2065 | test_acc: 0.9429
# Epoch: 5 | train_loss: 0.1470 | train_acc: 0.9595 | test_loss: 0.1523 | test_acc: 0.9579
# Epoch: 6 | train_loss: 0.1123 | train_acc: 0.9690 | test_loss: 0.1378 | test_acc: 0.9610
# Epoch: 7 | train_loss: 0.0867 | train_acc: 0.9754 | test_loss: 0.1020 | test_acc: 0.9707
# Epoch: 8 | train_loss: 0.0718 | train_acc: 0.9796 | test_loss: 0.0936 | test_acc: 0.9728
# Epoch: 9 | train_loss: 0.0659 | train_acc: 0.9810 | test_loss: 0.0728 | test_acc: 0.9791
# Epoch: 10 | train_loss: 0.0548 | train_acc: 0.9840 | test_loss: 0.0667 | test_acc: 0.9815
# Epoch: 11 | train_loss: 0.0485 | train_acc: 0.9859 | test_loss: 0.0730 | test_acc: 0.9785
# Epoch: 12 | train_loss: 0.0435 | train_acc: 0.9873 | test_loss: 0.0583 | test_acc: 0.9817
# Epoch: 13 | train_loss: 0.0418 | train_acc: 0.9877 | test_loss: 0.0712 | test_acc: 0.9799
# Epoch: 14 | train_loss: 0.0382 | train_acc: 0.9888 | test_loss: 0.0679 | test_acc: 0.9798
# Epoch: 15 | train_loss: 0.0342 | train_acc: 0.9898 | test_loss: 0.0598 | test_acc: 0.9826
# Epoch: 16 | train_loss: 0.0332 | train_acc: 0.9900 | test_loss: 0.0524 | test_acc: 0.9848
# Epoch: 17 | train_loss: 0.0339 | train_acc: 0.9898 | test_loss: 0.0573 | test_acc: 0.9834
# Epoch: 18 | train_loss: 0.0279 | train_acc: 0.9916 | test_loss: 0.0680 | test_acc: 0.9802
# Epoch: 19 | train_loss: 0.0287 | train_acc: 0.9913 | test_loss: 0.0564 | test_acc: 0.9843
# Epoch: 20 | train_loss: 0.0336 | train_acc: 0.9897 | test_loss: 0.0506 | test_acc: 0.9854
# Epoch: 21 | train_loss: 0.0261 | train_acc: 0.9920 | test_loss: 0.0518 | test_acc: 0.9844
# Epoch: 22 | train_loss: 0.0252 | train_acc: 0.9923 | test_loss: 0.0490 | test_acc: 0.9856
# Epoch: 23 | train_loss: 0.0249 | train_acc: 0.9924 | test_loss: 0.0638 | test_acc: 0.9823
# Epoch: 24 | train_loss: 0.0239 | train_acc: 0.9925 | test_loss: 0.0560 | test_acc: 0.9846
# Epoch: 25 | train_loss: 0.0247 | train_acc: 0.9922 | test_loss: 0.0564 | test_acc: 0.9841
# Epoch: 26 | train_loss: 0.0227 | train_acc: 0.9929 | test_loss: 0.0532 | test_acc: 0.9844
# Epoch: 27 | train_loss: 0.0222 | train_acc: 0.9932 | test_loss: 0.0536 | test_acc: 0.9860
# Epoch: 28 | train_loss: 0.0231 | train_acc: 0.9927 | test_loss: 0.0594 | test_acc: 0.9834
# Epoch: 29 | train_loss: 0.0235 | train_acc: 0.9925 | test_loss: 0.0604 | test_acc: 0.9822
# Epoch: 30 | train_loss: 0.0230 | train_acc: 0.9929 | test_loss: 0.0524 | test_acc: 0.9862
# Epoch: 31 | train_loss: 0.0226 | train_acc: 0.9930 | test_loss: 0.0503 | test_acc: 0.9859
# Epoch: 32 | train_loss: 0.0201 | train_acc: 0.9939 | test_loss: 0.0440 | test_acc: 0.9874
# Epoch: 33 | train_loss: 0.0212 | train_acc: 0.9931 | test_loss: 0.0559 | test_acc: 0.9843
# Epoch: 34 | train_loss: 0.0209 | train_acc: 0.9934 | test_loss: 0.0466 | test_acc: 0.9864
# Epoch: 35 | train_loss: 0.0202 | train_acc: 0.9937 | test_loss: 0.0696 | test_acc: 0.9810
# Epoch: 36 | train_loss: 0.0189 | train_acc: 0.9938 | test_loss: 0.0631 | test_acc: 0.9831
# Epoch: 37 | train_loss: 0.0205 | train_acc: 0.9935 | test_loss: 0.0511 | test_acc: 0.9855
# Epoch: 38 | train_loss: 0.0235 | train_acc: 0.9928 | test_loss: 0.0507 | test_acc: 0.9854
# Epoch: 39 | train_loss: 0.0212 | train_acc: 0.9932 | test_loss: 0.0477 | test_acc: 0.9864
# Epoch: 40 | train_loss: 0.0205 | train_acc: 0.9934 | test_loss: 0.0457 | test_acc: 0.9875
# Epoch: 41 | train_loss: 0.0207 | train_acc: 0.9933 | test_loss: 0.0518 | test_acc: 0.9856
# Epoch: 42 | train_loss: 0.0208 | train_acc: 0.9931 | test_loss: 0.0452 | test_acc: 0.9868
# Epoch: 43 | train_loss: 0.0198 | train_acc: 0.9938 | test_loss: 0.0460 | test_acc: 0.9875
# Epoch: 44 | train_loss: 0.0204 | train_acc: 0.9935 | test_loss: 0.0653 | test_acc: 0.9818
# Epoch: 45 | train_loss: 0.0244 | train_acc: 0.9922 | test_loss: 0.0475 | test_acc: 0.9868
# Epoch: 46 | train_loss: 0.0233 | train_acc: 0.9924 | test_loss: 0.0613 | test_acc: 0.9825
# Epoch: 47 | train_loss: 0.0198 | train_acc: 0.9936 | test_loss: 0.0645 | test_acc: 0.9815
# Epoch: 48 | train_loss: 0.0209 | train_acc: 0.9933 | test_loss: 0.0558 | test_acc: 0.9843
# Epoch: 49 | train_loss: 0.0202 | train_acc: 0.9935 | test_loss: 0.0465 | test_acc: 0.9862
# Epoch: 50 | train_loss: 0.0222 | train_acc: 0.9929 | test_loss: 0.0454 | test_acc: 0.9863
# Epoch: 51 | train_loss: 0.0226 | train_acc: 0.9930 | test_loss: 0.0806 | test_acc: 0.9773
# Epoch: 52 | train_loss: 0.0210 | train_acc: 0.9932 | test_loss: 0.0437 | test_acc: 0.9876
# Epoch: 53 | train_loss: 0.0235 | train_acc: 0.9923 | test_loss: 0.0452 | test_acc: 0.9868
# Epoch: 54 | train_loss: 0.0220 | train_acc: 0.9931 | test_loss: 0.0645 | test_acc: 0.9813
# Epoch: 55 | train_loss: 0.0223 | train_acc: 0.9928 | test_loss: 0.0675 | test_acc: 0.9810
# Epoch: 56 | train_loss: 0.0241 | train_acc: 0.9921 | test_loss: 0.0526 | test_acc: 0.9846
# Epoch: 57 | train_loss: 0.0219 | train_acc: 0.9930 | test_loss: 0.0771 | test_acc: 0.9779
# Epoch: 58 | train_loss: 0.0249 | train_acc: 0.9919 | test_loss: 0.0570 | test_acc: 0.9837
# Epoch: 59 | train_loss: 0.0210 | train_acc: 0.9930 | test_loss: 0.0560 | test_acc: 0.9840
# Epoch: 60 | train_loss: 0.0244 | train_acc: 0.9921 | test_loss: 0.0530 | test_acc: 0.9843
# Epoch: 61 | train_loss: 0.0222 | train_acc: 0.9927 | test_loss: 0.0437 | test_acc: 0.9878
# Epoch: 62 | train_loss: 0.0233 | train_acc: 0.9924 | test_loss: 0.0555 | test_acc: 0.9844
# Epoch: 63 | train_loss: 0.0247 | train_acc: 0.9919 | test_loss: 0.0515 | test_acc: 0.9852
# Epoch: 64 | train_loss: 0.0256 | train_acc: 0.9921 | test_loss: 0.0609 | test_acc: 0.9839
# Epoch: 65 | train_loss: 0.0232 | train_acc: 0.9925 | test_loss: 0.0602 | test_acc: 0.9834
# Epoch: 66 | train_loss: 0.0240 | train_acc: 0.9923 | test_loss: 0.0534 | test_acc: 0.9845
# Epoch: 67 | train_loss: 0.0411 | train_acc: 0.9875 | test_loss: 0.0576 | test_acc: 0.9840
# Epoch: 68 | train_loss: 0.0284 | train_acc: 0.9908 | test_loss: 0.0513 | test_acc: 0.9864
# Epoch: 69 | train_loss: 0.0296 | train_acc: 0.9907 | test_loss: 0.0975 | test_acc: 0.9722
# Epoch: 70 | train_loss: 0.0360 | train_acc: 0.9885 | test_loss: 0.0488 | test_acc: 0.9863
# Epoch: 71 | train_loss: 0.0267 | train_acc: 0.9913 | test_loss: 0.0530 | test_acc: 0.9867
# Epoch: 72 | train_loss: 0.0269 | train_acc: 0.9914 | test_loss: 0.0586 | test_acc: 0.9836
# Epoch: 73 | train_loss: 0.0259 | train_acc: 0.9915 | test_loss: 0.0508 | test_acc: 0.9867
# Epoch: 74 | train_loss: 0.0271 | train_acc: 0.9912 | test_loss: 0.0589 | test_acc: 0.9832
# Epoch: 75 | train_loss: 0.0309 | train_acc: 0.9901 | test_loss: 0.0615 | test_acc: 0.9829
# Epoch: 76 | train_loss: 0.0304 | train_acc: 0.9900 | test_loss: 0.0546 | test_acc: 0.9847
# Epoch: 77 | train_loss: 0.0312 | train_acc: 0.9902 | test_loss: 0.0682 | test_acc: 0.9810
# Epoch: 78 | train_loss: 0.0291 | train_acc: 0.9906 | test_loss: 0.0827 | test_acc: 0.9759
# Epoch: 79 | train_loss: 0.0359 | train_acc: 0.9887 | test_loss: 0.0711 | test_acc: 0.9804
# Epoch: 80 | train_loss: 0.0311 | train_acc: 0.9900 | test_loss: 0.0606 | test_acc: 0.9829
# Epoch: 81 | train_loss: 0.0337 | train_acc: 0.9889 | test_loss: 0.0618 | test_acc: 0.9824
# Epoch: 82 | train_loss: 0.0356 | train_acc: 0.9884 | test_loss: 0.0591 | test_acc: 0.9833
# Epoch: 83 | train_loss: 0.0324 | train_acc: 0.9896 | test_loss: 0.0663 | test_acc: 0.9809
# Epoch: 84 | train_loss: 0.0281 | train_acc: 0.9909 | test_loss: 0.0705 | test_acc: 0.9810
# Epoch: 85 | train_loss: 0.0364 | train_acc: 0.9886 | test_loss: 0.0660 | test_acc: 0.9805
# Epoch: 86 | train_loss: 0.0536 | train_acc: 0.9831 | test_loss: 0.0920 | test_acc: 0.9737
# Epoch: 87 | train_loss: 0.0393 | train_acc: 0.9872 | test_loss: 0.0638 | test_acc: 0.9811
# Epoch: 88 | train_loss: 0.0375 | train_acc: 0.9877 | test_loss: 0.0810 | test_acc: 0.9770
# Epoch: 89 | train_loss: 0.0364 | train_acc: 0.9881 | test_loss: 0.0810 | test_acc: 0.9771
# Epoch: 90 | train_loss: 0.0474 | train_acc: 0.9851 | test_loss: 0.0722 | test_acc: 0.9797
# Epoch: 91 | train_loss: 0.0493 | train_acc: 0.9843 | test_loss: 0.0860 | test_acc: 0.9761
# Epoch: 92 | train_loss: 0.0453 | train_acc: 0.9855 | test_loss: 0.0641 | test_acc: 0.9825
# Epoch: 93 | train_loss: 0.0428 | train_acc: 0.9864 | test_loss: 0.0696 | test_acc: 0.9794
# Epoch: 94 | train_loss: 0.0469 | train_acc: 0.9848 | test_loss: 0.0896 | test_acc: 0.9749
# Epoch: 95 | train_loss: 0.0669 | train_acc: 0.9791 | test_loss: 0.1039 | test_acc: 0.9711
# Epoch: 96 | train_loss: 0.0626 | train_acc: 0.9800 | test_loss: 0.0923 | test_acc: 0.9735
# Epoch: 97 | train_loss: 0.0667 | train_acc: 0.9791 | test_loss: 0.1420 | test_acc: 0.9603
# Epoch: 98 | train_loss: 0.0702 | train_acc: 0.9779 | test_loss: 0.0954 | test_acc: 0.9730
# Epoch: 99 | train_loss: 0.0803 | train_acc: 0.9750 | test_loss: 0.1573 | test_acc: 0.9563
# Epoch: 100 | train_loss: 0.0608 | train_acc: 0.9808 | test_loss: 0.1122 | test_acc: 0.9684

# %%
import matplotlib.pyplot as plt

def plot_history(result):
  acc = result['train_acc']
  val_acc = result['test_acc']
  loss = result['train_loss']
  val_loss = result['test_loss']
  x = range(1, len(acc) + 1)

  plt.figure(figsize=(12, 5))
  plt.subplot(1, 2, 1)
  plt.plot(x, acc, 'b', label='Training acc')
  plt.plot(x, val_acc, 'r', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.legend()

  plt.subplot(1, 2, 2)
  plt.plot(x, loss, 'b', label='Training loss')
  plt.plot(x, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.legend()

# %%
plot_history(result)

# %%
torch.save(obj=model.state_dict(), f='/content/gdrive/My Drive/Protein/model/protein_GRU.pth')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ebf54248bc7b> in <module>
# ----> 1 torch.save(obj=model.state_dict(), f='/content/gdrive/My Drive/Protein/model/protein_GRU.pth')
#
# NameError: name 'torch' is not defined
